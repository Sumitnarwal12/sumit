# %%
name = ["sumit","aryan"]
name.append("kumar")
print(name)
# Out:
# ['sumit', 'aryan', 'kumar']

# %%
a = [10,20,30]
a.insert(40,20)
print (a)
# Out:
# [10, 20, 30, 20]

# %%
a = [1,2,3]
b = [4,5,6]
a.extend(b)
print(a)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
set1 = {20,30,40}
set1.add(50)
print(set1)
# Out:
# {40, 50, 20, 30}

# %%
set1 = {20,30,40,50}
set1.update([60,70])
print(set1)
# Out:
# {70, 40, 50, 20, 60, 30}

# %%
set1 = {10,20,30,40,50,60,70}
set1.remove(20)
set1.remove(30)
print(set1)
# Out:
# {50, 70, 40, 10, 60}
